# %%
# %sql
CREATE OR REFRESH STREAMING TABLE bridge_monitoring.01_bronze.bridge_temperature
COMMENT "Raw temperature readings"
AS
SELECT 
    device_id,
    event_time,
    temperature
FROM STREAM delta.`/Volumes/bridge_monitoring/00_landing/streaming/bridge_temperature/`

# %%
# %sql
CREATE OR REFRESH STREAMING TABLE bridge_monitoring.`01_bronze`.bridge_tilt
COMMENT "Raw tilt readings"
AS
SELECT 
    device_id,
    event_time,
    tilt
FROM STREAM delta.`/Volumes/bridge_monitoring/00_landing/streaming/bridge_tilt/`

# %%
# %sql
CREATE OR REFRESH STREAMING TABLE bridge_monitoring.`01_bronze`.bridge_vibration
COMMENT "Raw vibration readings"
AS
SELECT 
    device_id,
    event_time,
    vibration
FROM STREAM delta.`/Volumes/bridge_monitoring/00_landing/streaming/bridge_vibration/`

# %%
# %sql
SELECT * FROM delta.`/Volumes/bridge_monitoring/00_landing/streaming/bridge_temperature/`

# %%
# %sql
SELECT * FROM delta.`/Volumes/bridge_monitoring/00_landing/streaming/bridge_tilt/`

# %%
# %sql
SELECT * FROM delta.`/Volumes/bridge_monitoring/00_landing/streaming/bridge_vibration/`
